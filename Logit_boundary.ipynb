# %%
import numpy as np
import pandas as pd
import seaborn as sn
import matplotlib.pyplot as plt
from pandas.tools.plotting import scatter_matrix
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn import tree
from sklearn import lda#discriminant_analysis
from patsy import dmatrices
import math
from pandas import DataFrame
# Out:
# /home/kavya-a/anaconda3/lib/python3.5/site-packages/sklearn/lda.py:4: DeprecationWarning: lda.LDA has been moved to discriminant_analysis.LinearDiscriminantAnalysis in 0.17 and will be removed in 0.19
#   "in 0.17 and will be removed in 0.19", DeprecationWarning)

# %%
# %matplotlib inline

# %%
plt.style.use('ggplot')

# %%
plt.rcParams['figure.figsize'] = (13,8)

# %%
df=pd.read_csv("./winequality-red.csv")

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %%
df.loc[df.quality > 5, 'category'] = 1
df.loc[df.quality <= 5, 'category'] = 0

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality  category
# 0      9.4        5       0.0
# 1      9.8        5       0.0
# 2      9.8        5       0.0
# 3      9.8        6       1.0
# 4      9.4        5       0.0

# %%
df.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.256131     0.671703
# volatile acidity          -0.256131          1.000000    -0.552496
# citric acid                0.671703         -0.552496     1.000000
# residual sugar             0.114777          0.001918     0.143577
# chlorides                  0.093705          0.061298     0.203823
# free sulfur dioxide       -0.153794         -0.010504    -0.060978
# total sulfur dioxide      -0.113181          0.076470     0.035533
# density                    0.668047          0.022026     0.364947
# pH                        -0.682978          0.234937    -0.541904
# sulphates                  0.183006         -0.260987     0.312770
# alcohol                   -0.061668         -0.202288     0.109903
# quality                    0.124052         -0.390558     0.226373
# category                   0.095093         -0.321441     0.159129
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# fixed acidity               0.114777   0.093705            -0.153794
# volatile acidity            0.001918   0.061298            -0.010504
# citric acid                 0.143577   0.203823            -0.060978
# residual sugar              1.000000   0.055610             0.187049
# chlorides                   0.055610   1.000000             0.005562
# free sulfur dioxide         0.187049   0.005562             1.000000
# total sulfur dioxide        0.203028   0.047400             0.667666
# density                     0.355283   0.200632            -0.021946
# pH                         -0.085652  -0.265026             0.070377
# sulphates                   0.005527   0.371260             0.051658
# alcohol                     0.042075  -0.221141            -0.069408
# quality                     0.013732  -0.128907            -0.050656
# category                   -0.002160  -0.109494            -0.061757
#
#                       total sulfur dioxide   density        pH  sulphates  \
# fixed acidity                    -0.113181  0.668047 -0.682978   0.183006
# volatile acidity                  0.076470  0.022026  0.234937  -0.260987
# citric acid                       0.035533  0.364947 -0.541904   0.312770
# residual sugar                    0.203028  0.355283 -0.085652   0.005527
# chlorides                         0.047400  0.200632 -0.265026   0.371260
# free sulfur dioxide               0.667666 -0.021946  0.070377   0.051658
# total sulfur dioxide              1.000000  0.071269 -0.066495   0.042947
# density                           0.071269  1.000000 -0.341699   0.148506
# pH                               -0.066495 -0.341699  1.000000  -0.196648
# sulphates                         0.042947  0.148506 -0.196648   1.000000
# alcohol                          -0.205654 -0.496180  0.205633   0.093595
# quality                          -0.185100 -0.174919 -0.057731   0.251397
# category                         -0.231963 -0.159110 -0.003264   0.218072
#
#                        alcohol   quality  category
# fixed acidity        -0.061668  0.124052  0.095093
# volatile acidity     -0.202288 -0.390558 -0.321441
# citric acid           0.109903  0.226373  0.159129
# residual sugar        0.042075  0.013732 -0.002160
# chlorides            -0.221141 -0.128907 -0.109494
# free sulfur dioxide  -0.069408 -0.050656 -0.061757
# total sulfur dioxide -0.205654 -0.185100 -0.231963
# density              -0.496180 -0.174919 -0.159110
# pH                    0.205633 -0.057731 -0.003264
# sulphates             0.093595  0.251397  0.218072
# alcohol               1.000000  0.476166  0.434751
# quality               0.476166  1.000000  0.848279
# category              0.434751  0.848279  1.000000

# %%
df_train=df.iloc[:500,]
df_test=df.iloc[500:,]

# %%
X = DataFrame()
X2 = DataFrame()
X3 = DataFrame()
y=df_train['category']
X['alcohol']=df_train['alcohol']
X['sulphates']=df_train['sulphates']
y2=df_test['category']
X2['alcohol']=df_test['alcohol']
X2['sulphates']=df_test['sulphates']
y3=df['category']
X3['alcohol']=df['alcohol']
X3['sulphates']=df['sulphates']

# %%
#model = LogisticRegression()
model = RandomForestClassifier(n_estimators=400)
#model = tree.DecisionTreeClassifier(max_depth = 100)
#model = lda.LDA()
X2
# Out:
#       alcohol  sulphates
# 500       9.0       0.65
# 501      12.0       0.85
# 502      12.0       0.85
# 503      10.9       1.04
# 504      10.8       1.05
# 505      12.5       0.78
# 506      10.8       1.02
# 507       9.5       0.71
# 508      10.2       0.63
# 509      11.4       0.68
# 510       9.5       0.61
# 511      10.2       0.63
# 512       9.7       0.81
# 513      11.8       0.66
# 514      11.8       0.66
# 515       9.3       1.14
# 516      11.9       0.74
# 517       8.4       0.63
# 518      11.7       0.68
# 519      11.0       0.78
# 520      10.0       0.90
# 521       9.1       0.64
# 522       9.8       0.99
# 523       9.4       0.55
# 524       9.5       0.64
# 525       9.9       0.67
# 526      11.0       0.78
# 527      11.4       0.77
# 528       8.7       0.75
# 529       9.4       0.57
# ...       ...        ...
# 1569     11.5       0.57
# 1570     12.4       0.93
# 1571     11.1       0.65
# 1572      9.5       0.51
# 1573     12.5       0.67
# 1574     10.5       0.48
# 1575     11.8       0.64
# 1576     10.8       0.78
# 1577     11.9       0.60
# 1578     11.3       0.67
# 1579     11.3       0.60
# 1580     11.9       0.60
# 1581     11.3       0.60
# 1582     11.9       0.50
# 1583      9.8       0.62
# 1584     11.6       0.80
# 1585     11.5       0.84
# 1586     11.4       0.85
# 1587     10.9       0.66
# 1588     12.8       0.78
# 1589      9.2       0.54
# 1590     11.6       0.82
# 1591     11.6       0.56
# 1592     11.0       0.75
# 1593      9.5       0.82
# 1594     10.5       0.58
# 1595     11.2       0.76
# 1596     11.0       0.75
# 1597     10.2       0.71
# 1598     11.0       0.66
#
# [1099 rows x 2 columns]

# %%
model = model.fit(X, y)

# %%
model.score(X,y)
# Out:
# 0.94599999999999995

# %%
model.score(X2,y2)
# Out:
# 0.65332120109190173

# %%
#p=DataFrame(list(zip(df['quality'],df['category'],df['category']*0)),columns=['quality','category','probability'])
p=DataFrame()
p['alcohol']=df['alcohol']
p['sulphates']=df['sulphates']
p['category']=df['category']

# %%
p
# Out:
#       alcohol  sulphates  category
# 0         9.4       0.56       0.0
# 1         9.8       0.68       0.0
# 2         9.8       0.65       0.0
# 3         9.8       0.58       1.0
# 4         9.4       0.56       0.0
# 5         9.4       0.56       0.0
# 6         9.4       0.46       0.0
# 7        10.0       0.47       1.0
# 8         9.5       0.57       1.0
# 9        10.5       0.80       0.0
# 10        9.2       0.54       0.0
# 11       10.5       0.80       0.0
# 12        9.9       0.52       0.0
# 13        9.1       1.56       0.0
# 14        9.2       0.88       0.0
# 15        9.2       0.93       0.0
# 16       10.5       0.75       1.0
# 17        9.3       1.28       0.0
# 18        9.0       0.50       0.0
# 19        9.2       1.08       1.0
# 20        9.4       0.53       1.0
# 21        9.7       0.65       0.0
# 22        9.5       0.91       0.0
# 23        9.4       0.53       0.0
# 24        9.7       0.63       1.0
# 25        9.3       0.56       0.0
# 26        9.5       0.59       0.0
# 27        9.5       0.91       0.0
# 28        9.4       0.55       0.0
# 29        9.8       0.59       1.0
# ...       ...        ...       ...
# 1569     11.5       0.57       1.0
# 1570     12.4       0.93       1.0
# 1571     11.1       0.65       1.0
# 1572      9.5       0.51       0.0
# 1573     12.5       0.67       1.0
# 1574     10.5       0.48       1.0
# 1575     11.8       0.64       1.0
# 1576     10.8       0.78       1.0
# 1577     11.9       0.60       1.0
# 1578     11.3       0.67       1.0
# 1579     11.3       0.60       0.0
# 1580     11.9       0.60       1.0
# 1581     11.3       0.60       0.0
# 1582     11.9       0.50       0.0
# 1583      9.8       0.62       0.0
# 1584     11.6       0.80       1.0
# 1585     11.5       0.84       1.0
# 1586     11.4       0.85       1.0
# 1587     10.9       0.66       1.0
# 1588     12.8       0.78       1.0
# 1589      9.2       0.54       0.0
# 1590     11.6       0.82       1.0
# 1591     11.6       0.56       1.0
# 1592     11.0       0.75       1.0
# 1593      9.5       0.82       1.0
# 1594     10.5       0.58       0.0
# 1595     11.2       0.76       1.0
# 1596     11.0       0.75       1.0
# 1597     10.2       0.71       0.0
# 1598     11.0       0.66       1.0
#
# [1599 rows x 3 columns]

# %%
#model.coef_

# %%
model.predict_proba(X3)[:,0]
# Out:
# array([ 0.999375  ,  0.53724405,  0.98208333, ...,  0.38      ,
#         0.21104167,  0.0675    ])

# %%
p['prob_0']=model.predict_proba(X3)[:,0]
p['prob_1']=model.predict_proba(X3)[:,1]
p['predicted']=model.predict(X3)

# %%
p
# Out:
#       alcohol  sulphates  category    prob_0    prob_1  predicted
# 0         9.4       0.56       0.0  0.999375  0.000625        0.0
# 1         9.8       0.68       0.0  0.537244  0.462756        0.0
# 2         9.8       0.65       0.0  0.982083  0.017917        0.0
# 3         9.8       0.58       1.0  0.327800  0.672200        1.0
# 4         9.4       0.56       0.0  0.999375  0.000625        0.0
# [1599 rows x 6 columns]

# %%
#ggplot(subset(p, quality in seq(4, 8, by=1))) + geom_point(aes(x = quality, y = probability, color = \
#factor(quality)), 
 #            size = 3, alpha = 1) + ggtitle("Quality vs. Purchase Probability at Various Prices") +  \
    #myScales +   scale_color_discrete("quality")

# %%
p.plot.scatter(x='alcohol', y='sulphates', c='prob_1', s=p['prob_1']*100)
#plot.xlim(0,10)

# %%
#using a scatter plot to depict the predicted qualities
ax = p[p.predicted == 1].plot(x="alcohol", y="sulphates", kind="scatter", color="green", label="HIGH", \
                                             s=100, alpha=0.5)
p[p.predicted == 0].plot(x="alcohol", y="sulphates", kind="scatter", color="red", label="LOW", \
                                        s=100, alpha=0.5, ax=ax)
"""Z = model.predict(X3)
xx=X3['alcohol']
yy=X3['sulphates']
Z = Z.reshape(xx.shape)
ax.contour(xx, yy, Z, cmap=plt.cm.Paired)"""
# Out:
# "Z = model.predict(X3)\nxx=X3['alcohol']\nyy=X3['sulphates']\nZ = Z.reshape(xx.shape)\nax.contour(xx, yy, Z, cmap=plt.cm.Paired)"

# %%
def meshj(p):
    h = .02  # step size in the mesh
    x_min, x_max = p['alcohol'].min() , p['alcohol'].max() + 1
    y_min, y_max = p['sulphates'].min() , p['sulphates'].max() + 1
    xx, yy = np.meshgrid(np.arange(x_min, x_max, h),np.arange(y_min, y_max, h))
    return xx, yy

# %%
xx, yy = meshj(p)
yy.shape
# Out:
# (134, 375)

# %%
xx.ravel().shape
# Out:
# (50250,)

# %%
Z = model.predict(np.c_[xx.ravel(), yy.ravel()])
p_plt=DataFrame()
p_plt['xx'] = xx.ravel()
p_plt['yy'] = yy.ravel()
p_plt['zz'] = Z
p_plt['proba_1'] = model.predict_proba(np.c_[xx.ravel(), yy.ravel()])[:,0]
Z.shape
# Out:
# (50250,)

# %%
ax = p_plt[p_plt.zz == 1].plot(x="xx", y="yy", kind="scatter", color="green", label="HIGH", \
                                             s=100, alpha=0.5)
p_plt[p_plt.zz == 0].plot(x="xx", y="yy", kind="scatter", color="red", label="LOW", \
                                        s=100, alpha=0.5, ax=ax)

# %%
p_boundary = DataFrame()
prob_boundary = 0.49
count = 0
for prob_val in p_plt['proba_1']:
    if (prob_val > prob_boundary and prob_val < 0.50):
        #print(prob_val)
        #p_boundary = 2
        count = count + 1
        
print(count)
# Out:
# 209

# %%
#p_boundary=p_plt.copy(deep = False)#.iloc[0]=p_plt.iloc[3]

# %%
#p_boundary

# %%
#p_boundary=p_plt.iloc[3]

# %%
#p_boundary

# %%
ax = p_plt[p_plt.zz == 1].plot(x="xx", y="yy", kind="scatter", color="green", label="HIGH", \
                                             s=20, alpha=0.1)
p_plt[p_plt.zz == 0].plot(x="xx", y="yy", kind="scatter", color="red", label="LOW", \
                                        s=20, alpha=0.1, ax=ax)
p_boundary = DataFrame()
prob_boundary = 0.47
count = 0
loop_var = 0
for prob_val in p_plt['proba_1']:
    loop_var = loop_var + 1
    if (prob_val >= prob_boundary and prob_val <= 0.53):
        count = count + 1
        ax.plot([p_plt.iloc[loop_var]['xx']],[p_plt.iloc[loop_var]['yy']],'bo', alpha=.5, ms=2)
#p[p.predicted == 1].plot(x="alcohol", y="sulphates", kind="scatter", color="green", label="HIGH", \
 #                                          s=40, alpha=1, ax = ax)
#p[p.predicted == 0].plot(x="alcohol", y="sulphates", kind="scatter", color="red", label="LOW", \
 #                                      s=40, alpha=1, ax = ax)

# %%
p_plt[(p_plt.proba_1>0.47) & (p_plt.proba_1<0.53)].count()
# Out:
# xx         1850
# yy         1850
# zz         1850
# proba_1    1850
# dtype: int64
